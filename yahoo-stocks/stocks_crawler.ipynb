# %% [markdown]
# # Web scraping Yahoo Finance Stocks Information
# This is a collaboration between Ruiz Lorenzo Chavez and Kennmar Pacificar as part of their requirements for their DAT100M class.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd
import json

# %%
def initialize_driver():
    
    driver = webdriver.Chrome()
    driver.refresh()
    driver.implicitly_wait(15)
    
    return driver

def extract_content(driver): 
    
    print("Extracting page")
    page = driver.page_source
    print("Extraction completed")
    
    return page

def next_page(driver):
    
    next_button = driver.find_element(By.XPATH, "//button[@aria-label='Goto next page']")
    next_button.click()
    print("Next page initialized")
    
    return extract_content(driver)

def extract_kpi(page_content):
    
    print("Extracting KPIs")
    
    soup = BeautifulSoup(page_content, "html.parser")
    
    symbol = [x.text.strip() for x in soup.find_all(class_="name yf-1m808gl stacked")]
    name = [x.text.strip() for x in soup.find_all(class_="yf-h8l7j7")]
    price = [x.text.strip() for x in soup.find_all("fin-streamer", {"data-test": "change", "data-field": "regularMarketPrice"})]
    abs_change = [x.text.strip() for x in soup.find_all("fin-streamer", {"data-test": "colorChange", "data-field": "regularMarketChange", "data-tstyle": "default"})]
    perc_change = [x.text.strip() for x in soup.find_all("fin-streamer", {"data-test": "colorChange", "data-field": "regularMarketChangePercent", "data-tstyle": "default"})]
    volume = [x.text.strip() for x in soup.find_all("fin-streamer", {"data-test": "change", "data-field": "regularMarketVolume"})]
    avg_vol_3m = [[y[7].text.strip() for y in [x.find_all("td") for x in soup.find_all("tr", class_="row false yf-paf8n5")]]][0]
    market_cap = [x.text.strip() for x in soup.find_all("fin-streamer", {"data-test": "change", "data-field": "marketCap"})]
    pe_ratio = [[y[9].text.strip() for y in [x.find_all("td") for x in soup.find_all("tr", class_="row false yf-paf8n5")]]][0]
    wk52_chg = [[y[10].text.strip() for y in [x.find_all("td") for x in soup.find_all("tr", class_="row false yf-paf8n5")]]][0]
    key_link = [x["href"] for x in soup.find_all("a", class_="ticker small tw-text-md hover stacked yf-1m808gl")]
    
    print("Extraction completed")
    
    return symbol, name, price, abs_change, perc_change, volume, avg_vol_3m, market_cap, pe_ratio, wk52_chg, key_link

def extract_statistics(page_content):
        
    print("Extracting statistics")
  
    soup = BeautifulSoup(page_content, "html.parser")
    
    stats_list = []
    
    for i in range(2):
        value_row = [x.text.strip() for x in soup.find_all(class_="column yf-14j5zka")[i].find_all(class_="value yf-vaowmx")]
        
        for value in value_row:
            stats_list.append(value)
        
    print("Extraction completed")
           
    return stats_list

def extract_stats_header(page_content):
    
    print("Extracting headers")
    
    soup = BeautifulSoup(page_content, "html.parser")
    
    header_list = []
    
    for i in range(2):
        header_value = [x.text.strip() for x in soup.find_all(class_="column yf-14j5zka")[i].find_all(class_="label yf-vaowmx")]
        
        for header in header_value:
            header_list.append(header)
            
    print("Extraction completed")
           
    return header_list

def append_kpi(extracted_kpi, kpi_dict):
    
    symbol, name, price, abs_change, perc_change, volume, avg_vol_3m, market_cap, pe_ratio, wk52_chg, key_link = extracted_kpi
    
    columns = ["symbol", "name", "price", "abs_change", "perc_change", "volume", "avg_vol_3m", "market_cap", "pe_ratio", "wk52_chg", "key_link"]
    values = [symbol, name, price, abs_change, perc_change, volume, avg_vol_3m, market_cap, pe_ratio, wk52_chg, key_link]
    
    if bool(kpi_dict):
        
        print("Pushing more data") 
        
        for index, column in enumerate(columns):
            kpi_dict[column] += values[index]
        
        print("Data pushed")
        print(f"Company stock data collected: {len(kpi_dict['symbol'])} companies\n")
        
    else:
        
        print("Populating dictionary")
          
        for index, column in enumerate(columns):
            kpi_dict[column] = (values[index])
                
        print("New data pushed")
        print(f"Company stock data collected: {len(kpi_dict['symbol'])} companies\n")   
        
def append_statistics(extracted_statistics, stats_dict, current_symbol, header):
    
    columns = header
    
    value_dict = dict(zip(columns, extracted_statistics))
    
    if bool(stats_dict):
        
        print("Pushing more data") 

        stats_dict['symbol'].append(current_symbol)
        
        for key in value_dict.keys():
            stats_dict[key].append(value_dict[key])
     
        print("Data pushed")
        print(f"{len(stats_dict['symbol'])} stock statistics collected\n")
        
    else:
        
        print("Populating dictionary")
        
        stats_dict['symbol'] = [current_symbol]
        
        for key in value_dict.keys():
            stats_dict[key] = [value_dict[key]]
            
        print("New data pushed")
        print(f"{len(stats_dict['symbol'])} stock statistics collected\n")

    return stats_dict

def export_json(stock_dict, filename):
    
    with open(f"./{filename}", 'w') as file:
        json.dump(stock_dict, file)
        
    print("Exported as JSON")

# %%
stock_kpi = {}

main_url = "https://finance.yahoo.com/markets/stocks/52-week-gainers/?start=0&count=100"

driver = initialize_driver()

driver.get(main_url)
print(f"Page initialized: {main_url}")

first_content = extract_content(driver)
first_kpi = extract_kpi(first_content)
append_kpi(first_kpi, stock_kpi)
    
while True:
    
    try:
        next_content = next_page(driver)
        
        sleep(15)
        
        next_kpi = extract_kpi(next_content)
        append_kpi(next_kpi, stock_kpi)
        
    except:
        print("No more pages left")
        break
    
driver.close()

print("\n=================================")
for key in stock_kpi.keys():
    print(f"{key}: {len(stock_kpi[key])}")
    
export_json(stock_kpi, "kpi.json")
# Out:
# Page initialized: https://finance.yahoo.com/markets/stocks/52-week-gainers/?start=0&count=100
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Populating dictionary
# New data pushed
# Company stock data collected: 100 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 200 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 300 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 400 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 500 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 600 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 700 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 800 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 900 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1000 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1100 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1200 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1300 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1400 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1500 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1600 companies
#
# Next page initialized
# Extracting page
# Extraction completed
# Extracting KPIs
# Extraction completed
# Pushing more data
# Data pushed
# Company stock data collected: 1700 companies
#
# No more pages left
#
# =================================
# symbol: 1700
# name: 1700
# price: 1700
# abs_change: 1700
# perc_change: 1700
# volume: 1700
# avg_vol_3m: 1700
# market_cap: 1700
# pe_ratio: 1700
# wk52_chg: 1700
# key_link: 1700
# Exported as JSON

# %%
key = stock_kpi["key_link"][0]

driver = initialize_driver()
stats_link = f"https://finance.yahoo.com{key}key-statistics/"
driver.get(stats_link)

page = extract_content(driver)
header = extract_stats_header(page)

driver.close()
# Out:
# Extracting page
# Extraction completed
# Extracting headers
# Extraction completed

# %%
stock_statistics = {}

symbols = [symbol for symbol in stock_kpi['symbol']]
key_links = [links for links in stock_kpi['key_link']]

driver = initialize_driver()

for index, key in enumerate(key_links):
        
    stats_link = f"https://finance.yahoo.com{key}key-statistics/"
    
    print(f"Accessing data from {symbols[index]}")
    
    driver.get(stats_link)
    
    statistics_page = extract_content(driver)
    
    try:
        statistics_content = extract_statistics(statistics_page)
        append_statistics(statistics_content, stock_statistics, symbols[index], header)
        
    except:
        pass
    
    sleep(15)

driver.close()

print("\n=================================")
for key in stock_statistics.keys():
    print(f"{key}: {len(stock_statistics[key])}")
    
export_json(stock_statistics, "statistics.json")
# Out:
# Accessing data from WGS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Populating dictionary
# New data pushed
# 1 stock statistics collected
#
# Accessing data from SEZL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 2 stock statistics collected
#
# Accessing data from LBPH
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 3 stock statistics collected
#
# Accessing data from SMR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 4 stock statistics collected
#
# Accessing data from APP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 5 stock statistics collected
#
# Accessing data from CHYI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 6 stock statistics collected
#
# Accessing data from SMMT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 7 stock statistics collected
#
# Accessing data from MSTR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 8 stock statistics collected
#
# Accessing data from CVNA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 9 stock statistics collected
#
# Accessing data from RKLB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 10 stock statistics collected
#
# Accessing data from RNA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 11 stock statistics collected
#
# Accessing data from CORZ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 12 stock statistics collected
#
# Accessing data from ADMA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 13 stock statistics collected
#
# Accessing data from WULF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 14 stock statistics collected
#
# Accessing data from EWTX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 15 stock statistics collected
#
# Accessing data from FMCKJ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 16 stock statistics collected
#
# Accessing data from JANX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 17 stock statistics collected
#
# Accessing data from FNMAS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 18 stock statistics collected
#
# Accessing data from ASTS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 19 stock statistics collected
#
# Accessing data from FMCC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 20 stock statistics collected
#
# Accessing data from LUMN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 21 stock statistics collected
#
# Accessing data from FNMAT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 22 stock statistics collected
#
# Accessing data from VST
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 23 stock statistics collected
#
# Accessing data from IESC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 24 stock statistics collected
#
# Accessing data from FNMA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 25 stock statistics collected
#
# Accessing data from NN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 26 stock statistics collected
#
# Accessing data from SG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 27 stock statistics collected
#
# Accessing data from SOUN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 28 stock statistics collected
#
# Accessing data from FTAI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 29 stock statistics collected
#
# Accessing data from HOOD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 30 stock statistics collected
#
# Accessing data from CAVA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 31 stock statistics collected
#
# Accessing data from SMTC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 32 stock statistics collected
#
# Accessing data from PLTR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 33 stock statistics collected
#
# Accessing data from TLN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 34 stock statistics collected
#
# Accessing data from HIMS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 35 stock statistics collected
#
# Accessing data from VERA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 36 stock statistics collected
#
# Accessing data from VKTX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 37 stock statistics collected
#
# Accessing data from USLM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 38 stock statistics collected
#
# Accessing data from EAT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 39 stock statistics collected
#
# Accessing data from SFM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 40 stock statistics collected
#
# Accessing data from RSI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 41 stock statistics collected
#
# Accessing data from GGAL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 42 stock statistics collected
#
# Accessing data from AGX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 43 stock statistics collected
#
# Accessing data from LB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 44 stock statistics collected
#
# Accessing data from TARS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 45 stock statistics collected
#
# Accessing data from CLS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 46 stock statistics collected
#
# Accessing data from BMA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 47 stock statistics collected
#
# Accessing data from BBAR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 48 stock statistics collected
#
# Accessing data from RDDT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 49 stock statistics collected
#
# Accessing data from NVDA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 50 stock statistics collected
#
# Accessing data from UI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 51 stock statistics collected
#
# Accessing data from TPL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 52 stock statistics collected
#
# Accessing data from STRL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 53 stock statistics collected
#
# Accessing data from SE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 54 stock statistics collected
#
# Accessing data from POWL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 55 stock statistics collected
#
# Accessing data from VRNA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 56 stock statistics collected
#
# Accessing data from TOST
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 57 stock statistics collected
#
# Accessing data from GEO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 58 stock statistics collected
#
# Accessing data from PCT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 59 stock statistics collected
#
# Accessing data from NTRA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 60 stock statistics collected
#
# Accessing data from VRT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 61 stock statistics collected
#
# Accessing data from COMP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 62 stock statistics collected
#
# Accessing data from INSM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 63 stock statistics collected
#
# Accessing data from CENX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 64 stock statistics collected
#
# Accessing data from QTWO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 65 stock statistics collected
#
# Accessing data from SRRK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 66 stock statistics collected
#
# Accessing data from AXON
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 67 stock statistics collected
#
# Accessing data from ZIM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 68 stock statistics collected
#
# Accessing data from LMND
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 69 stock statistics collected
#
# Accessing data from BTDR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 70 stock statistics collected
#
# Accessing data from HUT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 71 stock statistics collected
#
# Accessing data from AUR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 72 stock statistics collected
#
# Accessing data from BWIN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 73 stock statistics collected
#
# Accessing data from IONQ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 74 stock statistics collected
#
# Accessing data from PRIM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 75 stock statistics collected
#
# Accessing data from DYN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 76 stock statistics collected
#
# Accessing data from CRS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 77 stock statistics collected
#
# Accessing data from FIX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 78 stock statistics collected
#
# Accessing data from MOD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 79 stock statistics collected
#
# Accessing data from STEP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 80 stock statistics collected
#
# Accessing data from AGIO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 81 stock statistics collected
#
# Accessing data from WVE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 82 stock statistics collected
#
# Accessing data from QFIN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 83 stock statistics collected
#
# Accessing data from MMYT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 84 stock statistics collected
#
# Accessing data from COHR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 85 stock statistics collected
#
# Accessing data from CRDO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 86 stock statistics collected
#
# Accessing data from ZETA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 87 stock statistics collected
#
# Accessing data from CNTA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 88 stock statistics collected
#
# Accessing data from PRCT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 89 stock statistics collected
#
# Accessing data from YPF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 90 stock statistics collected
#
# Accessing data from IREN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 91 stock statistics collected
#
# Accessing data from RVLV
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 92 stock statistics collected
#
# Accessing data from SPOT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 93 stock statistics collected
#
# Accessing data from TGTX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 94 stock statistics collected
#
# Accessing data from IBKR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 95 stock statistics collected
#
# Accessing data from BRPHF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 96 stock statistics collected
#
# Accessing data from PTGX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 97 stock statistics collected
#
# Accessing data from UAL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 98 stock statistics collected
#
# Accessing data from RVMD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 99 stock statistics collected
#
# Accessing data from CLBT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 100 stock statistics collected
#
# Accessing data from WGS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 101 stock statistics collected
#
# Accessing data from SEZL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 102 stock statistics collected
#
# Accessing data from LBPH
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 103 stock statistics collected
#
# Accessing data from SMR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 104 stock statistics collected
#
# Accessing data from APP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 105 stock statistics collected
#
# Accessing data from CHYI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 106 stock statistics collected
#
# Accessing data from SMMT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 107 stock statistics collected
#
# Accessing data from MSTR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 108 stock statistics collected
#
# Accessing data from CVNA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 109 stock statistics collected
#
# Accessing data from RKLB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 110 stock statistics collected
#
# Accessing data from RNA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 111 stock statistics collected
#
# Accessing data from CORZ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 112 stock statistics collected
#
# Accessing data from ADMA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 113 stock statistics collected
#
# Accessing data from WULF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 114 stock statistics collected
#
# Accessing data from EWTX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 115 stock statistics collected
#
# Accessing data from FMCKJ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 116 stock statistics collected
#
# Accessing data from JANX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 117 stock statistics collected
#
# Accessing data from FNMAS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 118 stock statistics collected
#
# Accessing data from ASTS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 119 stock statistics collected
#
# Accessing data from FMCC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 120 stock statistics collected
#
# Accessing data from LUMN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 121 stock statistics collected
#
# Accessing data from FNMAT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 122 stock statistics collected
#
# Accessing data from VST
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 123 stock statistics collected
#
# Accessing data from IESC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 124 stock statistics collected
#
# Accessing data from FNMA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 125 stock statistics collected
#
# Accessing data from NN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 126 stock statistics collected
#
# Accessing data from SG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 127 stock statistics collected
#
# Accessing data from SOUN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 128 stock statistics collected
#
# Accessing data from FTAI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 129 stock statistics collected
#
# Accessing data from HOOD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 130 stock statistics collected
#
# Accessing data from CAVA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 131 stock statistics collected
#
# Accessing data from SMTC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 132 stock statistics collected
#
# Accessing data from PLTR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 133 stock statistics collected
#
# Accessing data from TLN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 134 stock statistics collected
#
# Accessing data from HIMS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 135 stock statistics collected
#
# Accessing data from VERA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 136 stock statistics collected
#
# Accessing data from VKTX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 137 stock statistics collected
#
# Accessing data from USLM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 138 stock statistics collected
#
# Accessing data from EAT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 139 stock statistics collected
#
# Accessing data from SFM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 140 stock statistics collected
#
# Accessing data from RSI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 141 stock statistics collected
#
# Accessing data from GGAL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 142 stock statistics collected
#
# Accessing data from AGX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 143 stock statistics collected
#
# Accessing data from LB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 144 stock statistics collected
#
# Accessing data from TARS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 145 stock statistics collected
#
# Accessing data from CLS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 146 stock statistics collected
#
# Accessing data from BMA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 147 stock statistics collected
#
# Accessing data from BBAR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 148 stock statistics collected
#
# Accessing data from RDDT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 149 stock statistics collected
#
# Accessing data from NVDA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 150 stock statistics collected
#
# Accessing data from UI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 151 stock statistics collected
#
# Accessing data from TPL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 152 stock statistics collected
#
# Accessing data from STRL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 153 stock statistics collected
#
# Accessing data from SE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 154 stock statistics collected
#
# Accessing data from POWL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 155 stock statistics collected
#
# Accessing data from VRNA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 156 stock statistics collected
#
# Accessing data from TOST
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 157 stock statistics collected
#
# Accessing data from GEO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 158 stock statistics collected
#
# Accessing data from PCT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 159 stock statistics collected
#
# Accessing data from NTRA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 160 stock statistics collected
#
# Accessing data from VRT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 161 stock statistics collected
#
# Accessing data from COMP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 162 stock statistics collected
#
# Accessing data from INSM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 163 stock statistics collected
#
# Accessing data from CENX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 164 stock statistics collected
#
# Accessing data from QTWO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 165 stock statistics collected
#
# Accessing data from SRRK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 166 stock statistics collected
#
# Accessing data from AXON
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 167 stock statistics collected
#
# Accessing data from ZIM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 168 stock statistics collected
#
# Accessing data from LMND
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 169 stock statistics collected
#
# Accessing data from BTDR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 170 stock statistics collected
#
# Accessing data from HUT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 171 stock statistics collected
#
# Accessing data from AUR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 172 stock statistics collected
#
# Accessing data from BWIN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 173 stock statistics collected
#
# Accessing data from IONQ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 174 stock statistics collected
#
# Accessing data from PRIM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 175 stock statistics collected
#
# Accessing data from DYN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 176 stock statistics collected
#
# Accessing data from CRS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 177 stock statistics collected
#
# Accessing data from FIX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 178 stock statistics collected
#
# Accessing data from MOD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 179 stock statistics collected
#
# Accessing data from STEP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 180 stock statistics collected
#
# Accessing data from AGIO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 181 stock statistics collected
#
# Accessing data from WVE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 182 stock statistics collected
#
# Accessing data from QFIN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 183 stock statistics collected
#
# Accessing data from MMYT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 184 stock statistics collected
#
# Accessing data from COHR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 185 stock statistics collected
#
# Accessing data from CRDO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 186 stock statistics collected
#
# Accessing data from ZETA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 187 stock statistics collected
#
# Accessing data from CNTA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 188 stock statistics collected
#
# Accessing data from PRCT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 189 stock statistics collected
#
# Accessing data from YPF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 190 stock statistics collected
#
# Accessing data from IREN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 191 stock statistics collected
#
# Accessing data from RVLV
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 192 stock statistics collected
#
# Accessing data from SPOT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 193 stock statistics collected
#
# Accessing data from TGTX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 194 stock statistics collected
#
# Accessing data from IBKR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 195 stock statistics collected
#
# Accessing data from BRPHF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 196 stock statistics collected
#
# Accessing data from PTGX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 197 stock statistics collected
#
# Accessing data from UAL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 198 stock statistics collected
#
# Accessing data from RVMD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 199 stock statistics collected
#
# Accessing data from CLBT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 200 stock statistics collected
#
# Accessing data from ROAD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 201 stock statistics collected
#
# Accessing data from ENVA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 202 stock statistics collected
#
# Accessing data from EME
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 203 stock statistics collected
#
# Accessing data from GEV
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 204 stock statistics collected
#
# Accessing data from CSWI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 205 stock statistics collected
#
# Accessing data from CNK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 206 stock statistics collected
#
# Accessing data from FITGF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 207 stock statistics collected
#
# Accessing data from SKYW
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 208 stock statistics collected
#
# Accessing data from RDNT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 209 stock statistics collected
#
# Accessing data from UPST
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 210 stock statistics collected
#
# Accessing data from TGS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 211 stock statistics collected
#
# Accessing data from TRGP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 212 stock statistics collected
#
# Accessing data from OKLO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 213 stock statistics collected
#
# Accessing data from AHR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 214 stock statistics collected
#
# Accessing data from CVLT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 215 stock statistics collected
#
# Accessing data from PI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 216 stock statistics collected
#
# Accessing data from GKOS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 217 stock statistics collected
#
# Accessing data from SATS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 218 stock statistics collected
#
# Accessing data from CIFR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 219 stock statistics collected
#
# Accessing data from MTZ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 220 stock statistics collected
#
# Accessing data from HWM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 221 stock statistics collected
#
# Accessing data from LLYVA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 222 stock statistics collected
#
# Accessing data from HBI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 223 stock statistics collected
#
# Accessing data from APGE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 224 stock statistics collected
#
# Accessing data from SOC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 225 stock statistics collected
#
# Accessing data from GERN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 226 stock statistics collected
#
# Accessing data from KYMR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 227 stock statistics collected
#
# Accessing data from KGS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 228 stock statistics collected
#
# Accessing data from CORT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 229 stock statistics collected
#
# Accessing data from SGHC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 230 stock statistics collected
#
# Accessing data from IAG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 231 stock statistics collected
#
# Accessing data from LLYVK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 232 stock statistics collected
#
# Accessing data from ARM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 233 stock statistics collected
#
# Accessing data from KKR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 234 stock statistics collected
#
# Accessing data from TGLS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 235 stock statistics collected
#
# Accessing data from DOCS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 236 stock statistics collected
#
# Accessing data from CEG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 237 stock statistics collected
#
# Accessing data from SN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 238 stock statistics collected
#
# Accessing data from SHAK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 239 stock statistics collected
#
# Accessing data from ALSN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 240 stock statistics collected
#
# Accessing data from JEF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 241 stock statistics collected
#
# Accessing data from PWP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 242 stock statistics collected
#
# Accessing data from RCL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 243 stock statistics collected
#
# Accessing data from AVPT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 244 stock statistics collected
#
# Accessing data from PAYO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 245 stock statistics collected
#
# Accessing data from VCTR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 246 stock statistics collected
#
# Accessing data from FRPT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 247 stock statistics collected
#
# Accessing data from HWKN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 248 stock statistics collected
#
# Accessing data from PIPR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 249 stock statistics collected
#
# Accessing data from CDE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 250 stock statistics collected
#
# Accessing data from GRND
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 251 stock statistics collected
#
# Accessing data from FICO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 252 stock statistics collected
#
# Accessing data from AAON
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 253 stock statistics collected
#
# Accessing data from NRG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 254 stock statistics collected
#
# Accessing data from WIX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 255 stock statistics collected
#
# Accessing data from COIN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 256 stock statistics collected
#
# Accessing data from GVA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 257 stock statistics collected
#
# Accessing data from OSCR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 258 stock statistics collected
#
# Accessing data from JXN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 259 stock statistics collected
#
# Accessing data from PAY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 260 stock statistics collected
#
# Accessing data from ERJ
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 261 stock statistics collected
#
# Accessing data from SOFI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 262 stock statistics collected
#
# Accessing data from ACIW
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 263 stock statistics collected
#
# Accessing data from PHIN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 264 stock statistics collected
#
# Accessing data from PAR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 265 stock statistics collected
#
# Accessing data from VIRT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 266 stock statistics collected
#
# Accessing data from FLEX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 267 stock statistics collected
#
# Accessing data from LGND
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 268 stock statistics collected
#
# Accessing data from WRBY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 269 stock statistics collected
#
# Accessing data from GWRE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 270 stock statistics collected
#
# Accessing data from HTLF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 271 stock statistics collected
#
# Accessing data from EVR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 272 stock statistics collected
#
# Accessing data from BFH
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 273 stock statistics collected
#
# Accessing data from SYF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 274 stock statistics collected
#
# Accessing data from MCY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 275 stock statistics collected
#
# Accessing data from THC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 276 stock statistics collected
#
# Accessing data from LITE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 277 stock statistics collected
#
# Accessing data from TPG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 278 stock statistics collected
#
# Accessing data from CALM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 279 stock statistics collected
#
# Accessing data from PPC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 280 stock statistics collected
#
# Accessing data from GDS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 281 stock statistics collected
#
# Accessing data from AS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 282 stock statistics collected
#
# Accessing data from MGNI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 283 stock statistics collected
#
# Accessing data from LMAT
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 284 stock statistics collected
#
# Accessing data from BROS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 285 stock statistics collected
#
# Accessing data from RYCEY
# Extracting page
# Extraction completed
# Extracting statistics
# Accessing data from SITM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 286 stock statistics collected
#
# Accessing data from ONON
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 287 stock statistics collected
#
# Accessing data from NFLX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 288 stock statistics collected
#
# ...
#
# Accessing data from UNJCF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1610 stock statistics collected
#
# Accessing data from AMH
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1611 stock statistics collected
#
# Accessing data from SKX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1612 stock statistics collected
#
# Accessing data from POOL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1613 stock statistics collected
#
# Accessing data from FMC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1614 stock statistics collected
#
# Accessing data from RLJ-PA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1615 stock statistics collected
#
# Accessing data from BOIVF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1616 stock statistics collected
#
# Accessing data from AGNC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1617 stock statistics collected
#
# Accessing data from SCGLY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1618 stock statistics collected
#
# Accessing data from GOGL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1619 stock statistics collected
#
# Accessing data from EQC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1620 stock statistics collected
#
# Accessing data from ES
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1621 stock statistics collected
#
# Accessing data from BIRK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1622 stock statistics collected
#
# Accessing data from BNL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1623 stock statistics collected
#
# Accessing data from STT-PG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1624 stock statistics collected
#
# Accessing data from SUN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1625 stock statistics collected
#
# Accessing data from ALGN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1626 stock statistics collected
#
# Accessing data from ALG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1627 stock statistics collected
#
# Accessing data from ABR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1628 stock statistics collected
#
# Accessing data from NVO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1629 stock statistics collected
#
# Accessing data from SHO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1630 stock statistics collected
#
# Accessing data from PDI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1631 stock statistics collected
#
# Accessing data from MS-PK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1632 stock statistics collected
#
# Accessing data from VOYA-PB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1633 stock statistics collected
#
# Accessing data from THO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1634 stock statistics collected
#
# Accessing data from SYY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1635 stock statistics collected
#
# Accessing data from ROK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1636 stock statistics collected
#
# Accessing data from HDB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1637 stock statistics collected
#
# Accessing data from ROP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1638 stock statistics collected
#
# Accessing data from TEX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1639 stock statistics collected
#
# Accessing data from ENS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1640 stock statistics collected
#
# Accessing data from OAK-PB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1641 stock statistics collected
#
# Accessing data from TFSL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1642 stock statistics collected
#
# Accessing data from HOG
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1643 stock statistics collected
#
# Accessing data from EXPI
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1644 stock statistics collected
#
# Accessing data from AVY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1645 stock statistics collected
#
# Accessing data from TEZNY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1646 stock statistics collected
#
# Accessing data from SNPS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1647 stock statistics collected
#
# Accessing data from CHX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1648 stock statistics collected
#
# Accessing data from HAE
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1649 stock statistics collected
#
# Accessing data from PTY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1650 stock statistics collected
#
# Accessing data from SBUX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1651 stock statistics collected
#
# Accessing data from WRD
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1652 stock statistics collected
#
# Accessing data from EADSY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1653 stock statistics collected
#
# Accessing data from SJM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1654 stock statistics collected
#
# Accessing data from GBDC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1655 stock statistics collected
#
# Accessing data from FLO
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1656 stock statistics collected
#
# Accessing data from BAC-PK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1657 stock statistics collected
#
# Accessing data from QGEN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1658 stock statistics collected
#
# Accessing data from UNP
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1659 stock statistics collected
#
# Accessing data from FMS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1660 stock statistics collected
#
# Accessing data from OTTR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1661 stock statistics collected
#
# Accessing data from SUHJY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1662 stock statistics collected
#
# Accessing data from CGNX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1663 stock statistics collected
#
# Accessing data from ARWR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1664 stock statistics collected
#
# Accessing data from PSX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1665 stock statistics collected
#
# Accessing data from RNR-PF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1666 stock statistics collected
#
# Accessing data from BLKB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1667 stock statistics collected
#
# Accessing data from NNN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1668 stock statistics collected
#
# Accessing data from O
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1669 stock statistics collected
#
# Accessing data from CMPR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1670 stock statistics collected
#
# Accessing data from EQX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1671 stock statistics collected
#
# Accessing data from WEX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1672 stock statistics collected
#
# Accessing data from ZS
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1673 stock statistics collected
#
# Accessing data from MTDR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1674 stock statistics collected
#
# Accessing data from KNX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1675 stock statistics collected
#
# Accessing data from CCK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1676 stock statistics collected
#
# Accessing data from LRCX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1677 stock statistics collected
#
# Accessing data from F
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1678 stock statistics collected
#
# Accessing data from AZN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1679 stock statistics collected
#
# Accessing data from REYN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1680 stock statistics collected
#
# Accessing data from ATHM
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1681 stock statistics collected
#
# Accessing data from OVV
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1682 stock statistics collected
#
# Accessing data from TEF
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1683 stock statistics collected
#
# Accessing data from SPSC
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1684 stock statistics collected
#
# Accessing data from YY
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1685 stock statistics collected
#
# Accessing data from PVH
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1686 stock statistics collected
#
# Accessing data from HES
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1687 stock statistics collected
#
# Accessing data from PSA-PK
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1688 stock statistics collected
#
# Accessing data from BL
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1689 stock statistics collected
#
# Accessing data from AMGN
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1690 stock statistics collected
#
# Accessing data from AVDX
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1691 stock statistics collected
#
# Accessing data from CTRA
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1692 stock statistics collected
#
# Accessing data from REXR-PB
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1693 stock statistics collected
#
# Accessing data from IPAR
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1694 stock statistics collected
#
# Accessing data from SOLV
# Extracting page
# Extraction completed
# Extracting statistics
# Extraction completed
# Pushing more data
# Data pushed
# 1695 stock statistics collected
#
#
# =================================
# symbol: 1695
# Fiscal Year Ends: 1695
# Most Recent Quarter  (mrq): 1695
# Profit Margin: 1695
# Operating Margin  (ttm): 1695
# Return on Assets  (ttm): 1695
# Return on Equity  (ttm): 1695
# Revenue  (ttm): 1695
# Revenue Per Share  (ttm): 1695
# Quarterly Revenue Growth  (yoy): 1695
# Gross Profit  (ttm): 1695
# EBITDA: 1695
# Net Income Avi to Common  (ttm): 1695
# Diluted EPS  (ttm): 1695
# Quarterly Earnings Growth  (yoy): 1695
# Total Cash  (mrq): 1695
# Total Cash Per Share  (mrq): 1695
# Total Debt  (mrq): 1695
# Total Debt/Equity  (mrq): 1695
# Current Ratio  (mrq): 1695
# Book Value Per Share  (mrq): 1695
# Operating Cash Flow  (ttm): 1695
# Levered Free Cash Flow  (ttm): 1695
# Beta (5Y Monthly): 1695
# 52 Week Range 3: 1695
# S&P 500 52-Week Change 3: 1695
# 52 Week High 3: 1695
# 52 Week Low 3: 1695
# 50-Day Moving Average 3: 1695
# 200-Day Moving Average 3: 1695
# Avg Vol (3 month) 3: 1695
# Avg Vol (10 day) 3: 1695
# Shares Outstanding 5: 1695
# Implied Shares Outstanding 6: 1695
# Float 8: 1695
# % Held by Insiders 1: 1695
# % Held by Institutions 1: 1695
# Shares Short (11/15/2024) 4: 1695
# Short Ratio (11/15/2024) 4: 1695
# Short % of Float (11/15/2024) 4: 1695
# Short % of Shares Outstanding (11/15/2024) 4: 1695
# Shares Short (prior month 10/15/2024) 4: 1695
# Forward Annual Dividend Rate 4: 1695
# Forward Annual Dividend Yield 4: 1695
# Trailing Annual Dividend Rate 3: 1695
# Trailing Annual Dividend Yield 3: 1695
# 5 Year Average Dividend Yield 4: 1695
# Payout Ratio 4: 1695
# Dividend Date 3: 1695
# Ex-Dividend Date 4: 1695
# Last Split Factor 2: 1695
# Last Split Date 3: 1695
# Exported as JSON

# %%
kpi_df = pd.DataFrame(stock_kpi).drop_duplicates(subset=["symbol"])
statistics_df = pd.DataFrame(stock_statistics).drop_duplicates(subset=["symbol"])

stocks_df = pd.merge(kpi_df, statistics_df, how="inner", on="symbol")
display(stocks_df)
stocks_df.to_json("stocks.json")
stocks_df.to_csv("stocks.csv")
# Out:
#        symbol                             name   price abs_change perc_change  \
# 0         WGS            GeneDx Holdings Corp.   78.39      -1.04      -1.31%
# 1        SEZL                      Sezzle Inc.  424.03      +9.08      +2.19%
# 2        LBPH  Longboard Pharmaceuticals, Inc.   59.98      +0.02      +0.03%
# 3         SMR        NuScale Power Corporation   29.65      +1.59      +5.67%
# 4         APP             AppLovin Corporation  336.75      +8.19      +2.49%
# ...       ...                              ...     ...        ...         ...
# 1590     AVDX       AvidXchange Holdings, Inc.   11.44       0.00       0.00%
# 1591     CTRA              Coterra Energy Inc.   26.72      +0.04      +0.15%
# 1592  REXR-PB  Rexford Industrial Realty, Inc.   23.10      +0.07      +0.31%
# 1593     IPAR               Interparfums, Inc.  137.66      -0.43      -0.31%
# 1594     SOLV            Solventum Corporation   71.51      -0.97      -1.34%
#
#        volume avg_vol_3m market_cap pe_ratio   wk52_chg  ...  \
# 0     185,783    591,117     2.182B        -  4,405.17%  ...
# 1      52,619    106,923     2.378B    44.82  4,098.32%  ...
# 2     655,798     1.737M     2.341B        -  1,414.65%  ...
# 3     11.514M    10.349M     2.998B        -    841.27%  ...
# 4      2.715M     5.499M   110.262B   102.05    801.12%  ...
# ...       ...        ...        ...      ...        ...  ...
# 1590  654,477     1.955M     2.354B        -      3.62%  ...
# 1591   2.485M     6.029M    19.682B    16.19      3.61%  ...
# 1592   18,879      7,524     3.895B    26.10      3.59%  ...
# 1593   77,888    147,522     4.423B    29.48      3.53%  ...
# 1594  576,974     1.107M    12.521B   188.18      3.49%  ...
#
#      Forward Annual Dividend Rate 4 Forward Annual Dividend Yield 4  \
# 0                                --                              --
# 1                                --                              --
# 2                                --                              --
# 3                                --                              --
# 4                                --                              --
# ...                             ...                             ...
# 1590                             --                              --
# 1591                           0.84                           3.14%
# 1592                           1.47                           6.36%
# 1593                              3                           2.18%
# 1594                             --                              --
#
#      Trailing Annual Dividend Rate 3 Trailing Annual Dividend Yield 3  \
# 0                               0.00                            0.00%
# 1                               0.00                            0.00%
# 2                               0.00                            0.00%
# 3                               0.00                            0.00%
# 4                               0.00                            0.00%
# ...                              ...                              ...
# 1590                            0.00                            0.00%
# 1591                            0.83                            3.11%
# 1592                            1.63                            7.09%
# 1593                            2.88                            2.08%
# 1594                            0.00                            0.00%
#
#      5 Year Average Dividend Yield 4 Payout Ratio 4 Dividend Date 3  \
# 0                                 --          0.00%              --
# 1                                 --          0.00%              --
# 2                                 --          0.00%              --
# 3                                 --          0.00%              --
# 4                                 --          0.00%              --
# ...                              ...            ...             ...
# 1590                              --          0.00%              --
# 1591                            4.29         50.30%      11/27/2024
# 1592                            6.01             --      12/31/2024
# 1593                            1.68         61.56%      12/31/2024
# 1594                              --          0.00%              --
#
#      Ex-Dividend Date 4 Last Split Factor 2 Last Split Date 3
# 0                    --                1:33          5/4/2023
# 1                    --                  --                --
# 2                    --                  --                --
# 3                    --                  --                --
# 4                    --                  --                --
# ...                 ...                 ...               ...
# 1590                 --                  --                --
# 1591         11/14/2024                 2:1         8/15/2013
# 1592         12/16/2024                  --                --
# 1593         12/16/2024                 3:2          6/2/2008
# 1594                 --                  --                --
#
# [1595 rows x 62 columns]
